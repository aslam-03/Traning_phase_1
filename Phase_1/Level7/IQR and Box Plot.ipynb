# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= [1, 2, 3, 4, 5, 6, 7, 8, 9, 20]

Q1=np.percentile(data,25)
Q3=np.percentile(data,75)

IQR=Q3-Q1

print("IQR : ",IQR)

plt.boxplot(data)
plt.title("Box Plot of Outlier")
plt.show()
# Out:
# IQR :  4.5
